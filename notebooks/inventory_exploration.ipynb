# %% [markdown]
# # Makerspace Inventory Exploration
#
# A compact notebook for exploring the sanitized sample inventory dataset.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if (PROJECT_ROOT / 'src').exists():
    sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from makerspace_inventory.loaders import load_inventory_csv
from makerspace_inventory.analysis import summarize, rank_followups, detect_duplicate_names

items = load_inventory_csv(PROJECT_ROOT / 'data' / 'sample_inventory.csv')
summarize(items)

# %%
rank_followups(items, limit=10)

# %%
detect_duplicate_names(items, threshold=0.74, limit=10)
